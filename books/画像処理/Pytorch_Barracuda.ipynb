# %%
# !nvidia-smi

# %%
# !pip install icrawler
# Out:
# Collecting icrawler
#   Downloading icrawler-0.6.6-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from icrawler) (1.15.0)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.7/dist-packages (from icrawler) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from icrawler) (4.2.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from icrawler) (7.1.2)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from icrawler) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->icrawler) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->icrawler) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->icrawler) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->icrawler) (2.10)
# Installing collected packages: icrawler
# Successfully installed icrawler-0.6.6

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from icrawler.builtin import BingImageCrawler
import shutil
import os

# %% [markdown]
# # 学習用画像の用意

# %%
# 猫の画像を100枚取得
crawler = BingImageCrawler(storage={"root_dir": "drive/MyDrive/Colab Notebooks/dataset/inuneko/train/cat"})
crawler.crawl(keyword="Cat", max_num=100)
# Out:
# 2021-10-28 06:28:32,643 - INFO - icrawler.crawler - start crawling...
# 2021-10-28 06:28:32,646 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2021-10-28 06:28:32,658 - INFO - feeder - thread feeder-001 exit
# 2021-10-28 06:28:32,658 - INFO - icrawler.crawler - starting 1 parser threads...
# 2021-10-28 06:28:32,674 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2021-10-28 06:28:32,943 - INFO - parser - parsing result page https://www.bing.com/images/async?q=Cat&first=0
# 2021-10-28 06:28:34,481 - ERROR - downloader - Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Cat_November_2010-1a.jpg
# 2021-10-28 06:28:34,550 - INFO - downloader - image #1	https://www.thesprucepets.com/thmb/A-lj23wOXsDRc_m3xNlwTl-tGPU=/6200x4138/filters:fill(auto,1)/GettyImages-523693627-976d1977942142c8b171a95057791a3e.jpg
# 2021-10-28 06:28:34,611 - INFO - downloader - image #2	https://pbs.twimg.com/media/DUfDNvTVQAA2osS.jpg
# 2021-10-28 06:28:34,637 - INFO - downloader - image #3	https://www.thesprucepets.com/thmb/AlsaZ1vMyplHqJkbe-iKeyzJwRY=/4368x2912/filters:fill(auto,1)/burmese-cat-love-85151671-5c87d723c9e77c0001a3e5ae.jpg
# 2021-10-28 06:28:34,955 - INFO - downloader - image #4	http://www.thestar.com/content/dam/thestar/business/2013/09/18/grumpy_cat_rewarded_for_persistent_frowning_gets_endorsement_deal/grumpy_cat.jpg
# 2021-10-28 06:28:35,041 - INFO - downloader - image #5	https://www.readersdigest.ca/wp-content/uploads/2020/02/GettyImages-1202925582-e1582140494731.jpg
# 2021-10-28 06:28:35,602 - INFO - downloader - image #6	https://www.siberiancatsinformation.com/wp-content/uploads/2020/06/45502005281_db333d028c_o-scaled.jpg
# 2021-10-28 06:28:35,753 - INFO - downloader - image #7	https://www.fetchfind.com/blog/wp-content/uploads/2017/08/cat-2734999_1920-5-common-cat-sounds.jpg
# 2021-10-28 06:28:36,892 - INFO - downloader - image #8	https://aboutcats.info/wp-content/uploads/2020/10/Balinese-Cat.jpg
# 2021-10-28 06:28:36,916 - INFO - downloader - image #9	https://www.thesprucepets.com/thmb/5tDHikYVxrJXwQCgVhacYo5PS4g=/2121x1414/filters:fill(auto,1)/Madelein_WolfGettyImages-845007724-cff4995e51a749e0a69f529c75447f5b.jpg
# 2021-10-28 06:28:37,881 - INFO - downloader - image #10	https://ukmadcat.com/wp-content/uploads/2019/04/sleepy-cat.jpg
# 2021-10-28 06:28:38,109 - INFO - downloader - image #11	https://viralcats.net/blog/wp-content/uploads/2017/10/saddest-shelter-cat-benben-transformation-8-9-Viral-Cats.jpg
# 2021-10-28 06:28:38,199 - INFO - downloader - image #12	http://www.100hdwallpapers.com/wallpapers/2560x1600/curious_cat-widescreen_wallpapers.jpg
# 2021-10-28 06:28:38,938 - INFO - downloader - image #13	https://www.advantagepetcare.com.au/sites/g/files/adhwdz311/files/styles/paragraph_image/public/2020-07/istock-539027929_unrestricted_1110x800.jpg
# 2021-10-28 06:28:39,008 - INFO - downloader - image #14	https://d.newsweek.com/en/full/1504969/black-cat-kitten-pet-animal-stock-getty.jpg
# 2021-10-28 06:28:39,058 - ERROR - downloader - Exception caught when downloading file https://reasonablecontent.com/wp-content/uploads/2020/12/This-angry-face-hides-an-absolutely-charming-cat-5fd32e3ce9553__880.jpg, error: HTTPSConnectionPool(host='reasonablecontent.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/12/This-angry-face-hides-an-absolutely-charming-cat-5fd32e3ce9553__880.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fbc53050b50>: Failed to establish a new connection: [Errno 111] Connection refused')), remaining retry times: 2
# 2021-10-28 06:28:39,072 - ERROR - downloader - Exception caught when downloading file https://reasonablecontent.com/wp-content/uploads/2020/12/This-angry-face-hides-an-absolutely-charming-cat-5fd32e3ce9553__880.jpg, error: HTTPSConnectionPool(host='reasonablecontent.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/12/This-angry-face-hides-an-absolutely-charming-cat-5fd32e3ce9553__880.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fbc52fda450>: Failed to establish a new connection: [Errno 111] Connection refused')), remaining retry times: 1
# 2021-10-28 06:28:39,086 - ERROR - downloader - Exception caught when downloading file https://reasonablecontent.com/wp-content/uploads/2020/12/This-angry-face-hides-an-absolutely-charming-cat-5fd32e3ce9553__880.jpg, error: HTTPSConnectionPool(host='reasonablecontent.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/12/This-angry-face-hides-an-absolutely-charming-cat-5fd32e3ce9553__880.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fbc52fda150>: Failed to establish a new connection: [Errno 111] Connection refused')), remaining retry times: 0
# 2021-10-28 06:28:39,168 - ERROR - downloader - Exception caught when downloading file https://www.daysoftheyear.com/cdn-cgi/image/fit=cover%2Cf=auto%2Conerror=redirect%2Cwidth=2560/wp-content/uploads/ginger-cat-appreciation-day.jpg, error: ('Connection aborted.', HTTPException('got more than 100 headers')), remaining retry times: 2
# 2021-10-28 06:28:39,241 - ERROR - downloader - Exception caught when downloading file https://www.daysoftheyear.com/cdn-cgi/image/fit=cover%2Cf=auto%2Conerror=redirect%2Cwidth=2560/wp-content/uploads/ginger-cat-appreciation-day.jpg, error: ('Connection aborted.', HTTPException('got more than 100 headers')), remaining retry times: 1
# 2021-10-28 06:28:39,324 - INFO - downloader - image #15	https://www.daysoftheyear.com/cdn-cgi/image/fit=cover%2Cf=auto%2Conerror=redirect%2Cwidth=2560/wp-content/uploads/ginger-cat-appreciation-day.jpg
# 2021-10-28 06:28:40,144 - INFO - downloader - image #16	https://wallup.net/wp-content/uploads/2016/03/12/305164-nature-cat.jpg
# 2021-10-28 06:28:40,937 - INFO - downloader - image #17	https://wallup.net/wp-content/uploads/2018/09/25/621670-cat-animals-kittens.jpg
# 2021-10-28 06:28:41,658 - INFO - downloader - image #18	http://www.katyjon.com/wp-content/uploads/2014/10/Tabby-macro.jpg
# 2021-10-28 06:28:44,720 - INFO - downloader - image #19	https://www.hdwallpapers.in/download/brown_black_cat_is_lying_down_on_chair_in_blur_background_hd_kitten-HD.jpg
# 2021-10-28 06:28:44,813 - INFO - downloader - image #20	https://www.statesman.com/storyimage/TX/20190517/NEWS/190518979/AR/0/AR-190518979.jpg
# 2021-10-28 06:28:44,870 - INFO - downloader - image #21	https://petsreporter.com/wp-content/uploads/2020/11/Weird-Cat-Behaviors-Explained-6-1.jpg
# 2021-10-28 06:28:45,929 - INFO - parser - parsing result page https://www.bing.com/images/async?q=Cat&first=20
# 2021-10-28 06:28:46,073 - INFO - downloader - image #22	https://britishexpats.com/forum/attachments/lounge-7/128430d1504097147-kitty-cat-thread-image-01.jpg
# 2021-10-28 06:28:46,586 - INFO - downloader - image #23	https://kenthumane.org/wp-content/uploads/2017/10/Betty-1.jpg
# 2021-10-28 06:28:46,853 - INFO - downloader - image #24	https://pulpbits.net/wp-content/uploads/2014/01/Calico-Siberian-Cat-1024x776.jpg
# 2021-10-28 06:28:46,908 - INFO - downloader - image #25	https://mymodernmet.com/wp/wp-content/uploads/2017/03/gabrielius-khiterer-stray-cats-11.jpg
# 2021-10-28 06:28:47,732 - INFO - downloader - image #26	https://catpedia.net/wp-content/uploads/2018/01/Chartreux-cat.jpg
# 2021-10-28 06:28:49,128 - INFO - downloader - image #27	https://blogs.columbian.com/cat-tales/wp-content/uploads/sites/43/2017/09/Sawyer_DS_1402.jpg
# 2021-10-28 06:28:49,168 - INFO - downloader - image #28	https://pbs.twimg.com/media/Dys_ovoXcAERzFA.jpg
# 2021-10-28 06:28:49,660 - INFO - downloader - image #29	https://wallup.net/wp-content/uploads/2017/11/23/498099-animals-feline-cat.jpg
# 2021-10-28 06:28:50,304 - INFO - downloader - image #30	https://wallup.net/wp-content/uploads/2017/11/23/434425-cat-heterochromia.jpg
# 2021-10-28 06:28:50,314 - INFO - downloader - skip downloading file 000031.jpg
# 2021-10-28 06:28:50,318 - INFO - downloader - skip downloading file 000032.jpg
# 2021-10-28 06:28:50,321 - INFO - downloader - skip downloading file 000033.jpg
# 2021-10-28 06:28:50,325 - INFO - downloader - skip downloading file 000034.jpg
# 2021-10-28 06:28:50,328 - INFO - downloader - skip downloading file 000035.jpg
# 2021-10-28 06:28:50,330 - INFO - downloader - skip downloading file 000036.jpg
# 2021-10-28 06:28:50,335 - INFO - downloader - skip downloading file 000037.jpg
# 2021-10-28 06:28:50,337 - INFO - downloader - skip downloading file 000038.jpg
# 2021-10-28 06:28:50,339 - INFO - downloader - skip downloading file 000039.jpg
# 2021-10-28 06:28:50,341 - INFO - downloader - skip downloading file 000040.jpg
# 2021-10-28 06:28:50,344 - INFO - downloader - skip downloading file 000041.jpg
# 2021-10-28 06:28:50,346 - INFO - downloader - skip downloading file 000042.jpg
# 2021-10-28 06:28:50,552 - INFO - parser - parsing result page https://www.bing.com/images/async?q=Cat&first=40
# 2021-10-28 06:28:50,573 - INFO - downloader - skip downloading file 000043.jpg
# 2021-10-28 06:28:50,576 - INFO - downloader - skip downloading file 000044.jpg
# 2021-10-28 06:28:50,578 - INFO - downloader - skip downloading file 000045.jpg
# 2021-10-28 06:28:50,579 - INFO - downloader - skip downloading file 000046.jpg
# 2021-10-28 06:28:50,582 - INFO - downloader - skip downloading file 000047.jpg
# 2021-10-28 06:28:50,583 - INFO - downloader - skip downloading file 000048.jpg
# 2021-10-28 06:28:50,585 - INFO - downloader - skip downloading file 000049.jpg
# 2021-10-28 06:28:50,587 - INFO - downloader - skip downloading file 000050.jpg
# 2021-10-28 06:28:50,589 - INFO - downloader - skip downloading file 000051.jpg
# 2021-10-28 06:28:50,591 - INFO - downloader - skip downloading file 000052.jpg
# 2021-10-28 06:28:50,593 - INFO - downloader - skip downloading file 000053.jpg
# 2021-10-28 06:28:50,594 - INFO - downloader - skip downloading file 000054.jpg
# 2021-10-28 06:28:50,596 - INFO - downloader - skip downloading file 000055.jpg
# 2021-10-28 06:28:50,610 - INFO - downloader - skip downloading file 000056.jpg
# 2021-10-28 06:28:50,625 - INFO - downloader - skip downloading file 000057.jpg
# 2021-10-28 06:28:50,628 - INFO - downloader - skip downloading file 000058.jpg
# 2021-10-28 06:28:50,632 - INFO - downloader - skip downloading file 000059.jpg
# 2021-10-28 06:28:50,636 - INFO - downloader - skip downloading file 000060.jpg
# 2021-10-28 06:28:50,822 - INFO - parser - parsing result page https://www.bing.com/images/async?q=Cat&first=60
# 2021-10-28 06:28:50,847 - INFO - downloader - skip downloading file 000061.jpg
# 2021-10-28 06:28:50,852 - INFO - downloader - skip downloading file 000062.jpg
# 2021-10-28 06:28:50,854 - INFO - downloader - skip downloading file 000063.jpg
# 2021-10-28 06:28:50,857 - INFO - downloader - skip downloading file 000064.jpg
# 2021-10-28 06:28:50,860 - INFO - downloader - skip downloading file 000065.jpg
# 2021-10-28 06:28:50,863 - INFO - downloader - skip downloading file 000066.jpg
# 2021-10-28 06:28:50,867 - INFO - downloader - skip downloading file 000067.jpg
# 2021-10-28 06:28:50,873 - INFO - downloader - skip downloading file 000068.jpg
# 2021-10-28 06:28:50,877 - INFO - downloader - skip downloading file 000069.jpg
# 2021-10-28 06:28:50,879 - INFO - downloader - skip downloading file 000070.jpg
# 2021-10-28 06:28:50,882 - INFO - downloader - skip downloading file 000071.jpg
# 2021-10-28 06:28:50,884 - INFO - downloader - skip downloading file 000072.jpg
# 2021-10-28 06:28:50,890 - INFO - downloader - skip downloading file 000073.jpg
# 2021-10-28 06:28:50,894 - INFO - downloader - skip downloading file 000074.jpg
# 2021-10-28 06:28:50,897 - INFO - downloader - skip downloading file 000075.jpg
# 2021-10-28 06:28:50,900 - INFO - downloader - skip downloading file 000076.jpg
# 2021-10-28 06:28:50,901 - INFO - downloader - skip downloading file 000077.jpg
# 2021-10-28 06:28:50,903 - INFO - downloader - skip downloading file 000078.jpg
# 2021-10-28 06:28:51,115 - INFO - parser - parsing result page https://www.bing.com/images/async?q=Cat&first=80
# 2021-10-28 06:28:51,137 - INFO - downloader - skip downloading file 000079.jpg
# 2021-10-28 06:28:51,141 - INFO - downloader - skip downloading file 000080.jpg
# 2021-10-28 06:28:51,144 - INFO - downloader - skip downloading file 000081.jpg
# 2021-10-28 06:28:51,658 - INFO - downloader - image #82	https://img.thrfun.com/img/191/908/what_breed_is_my_cat_16_x3.jpg
# 2021-10-28 06:28:51,762 - INFO - downloader - image #83	https://img.izismile.com/img/img13/20200604/640/thats_not_a_grumpy_cat_thats_a_mad_cat_640_high_02.jpg
# 2021-10-28 06:28:52,356 - INFO - downloader - image #84	http://www.allaboutthekitties.org/wp-content/uploads/2019/07/IMG_4205.jpg
# 2021-10-28 06:28:52,465 - INFO - downloader - image #85	https://www.kidsdiscover.com/wp-content/uploads/2015/03/Pallass-Cat.jpg
# 2021-10-28 06:28:53,454 - INFO - downloader - image #86	https://www.hdwallpapers.in/download/cute_cat_is_lying_down_on_a_floor_in_a_blur_background_hd_animals-1920x1080.jpg
# 2021-10-28 06:28:55,037 - INFO - downloader - image #87	https://www.vets4pets.com/siteassets/species/cat/cat-yawning-with-teeth.jpg
# 2021-10-28 06:28:55,279 - INFO - downloader - image #88	https://www.quizony.com/should-i-get-a-cat/imageForSharing.jpg
# 2021-10-28 06:28:56,096 - INFO - downloader - image #89	http://jigsawpuzzles.online/king-include/uploads/cat-portrait-domestic-cute-pet-feline-kitty-1553329993.jpg
# 2021-10-28 06:28:56,768 - INFO - downloader - image #90	https://www.taxidermyuk.net/wp-content/uploads/2016/06/mittens_02.jpg
# 2021-10-28 06:28:56,973 - INFO - downloader - image #91	https://img2.grunge.com/img/gallery/the-dumbest-cat-breed-in-the-world/the-stupid-cat-was-inside-you-all-along-1575042129.jpg
# 2021-10-28 06:28:57,070 - INFO - downloader - image #92	https://post.healthline.com/wp-content/uploads/2020/09/4609-cat-1200x628-facebook-1200x628.jpg
# 2021-10-28 06:28:57,467 - INFO - parser - no more page urls for thread parser-001 to parse
# 2021-10-28 06:28:57,469 - INFO - parser - thread parser-001 exit
# 2021-10-28 06:28:57,753 - INFO - downloader - image #93	https://www.advantagepetcare.com.au/sites/g/files/adhwdz311/files/styles/paragraph_image/public/2019-06/34_cat_adult_bringing_adult_cat_home-edited.jpg
# 2021-10-28 06:28:57,905 - INFO - downloader - image #94	https://img.playbuzz.com/image/upload/ar_1.5,c_pad,f_jpg,b_auto/cdn/288a2071-2918-40a0-861d-ef544b0657bc/14a60ac8-b3a8-4f23-8064-83dc7369ad16.jpg
# 2021-10-28 06:29:03,049 - INFO - downloader - no more download task for thread downloader-001
# 2021-10-28 06:29:03,052 - INFO - downloader - thread downloader-001 exit
# 2021-10-28 06:29:03,711 - INFO - icrawler.crawler - Crawling task done!

# %%
os.makedirs('drive/MyDrive/Colab Notebooks/dataset/inuneko/test/cat', exist_ok=True)

# %%
# 30枚を検証データに
for filenum in range(30):
  shutil.move('drive/MyDrive/Colab Notebooks/dataset/inuneko/train/cat/' +str(filenum+1).zfill(6)+'.jpg', 'drive/MyDrive/Colab Notebooks/dataset/inuneko/test/cat')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-9-49aff3b39fad> in <module>()
#       1 # 30枚を検証データに
#       2 for filenum in range(30):
# ----> 3   shutil.move('drive/MyDrive/Colab Notebooks/dataset/inuneko/train/cat/' +str(filenum+1).zfill(6)+'.jpg', 'drive/MyDrive/Colab Notebooks/dataset/inuneko/test/cat')
#
# /usr/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     562         real_dst = os.path.join(dst, _basename(src))
#     563         if os.path.exists(real_dst):
# --> 564             raise Error("Destination path '%s' already exists" % real_dst)
#     565     try:
#     566         os.rename(src, real_dst)
#
# Error: Destination path 'drive/MyDrive/Colab Notebooks/dataset/inuneko/test/cat/000001.jpg' already exists

# %%
# 犬の画像を100枚取得
crawler = BingImageCrawler(storage={"root_dir": "drive/MyDrive/Colab Notebooks/dataset/inuneko/train/dog"})
crawler.crawl(keyword="Dog", max_num=100)

# %%
os.makedirs('drive/MyDrive/Colab Notebooks/dataset/inuneko/test/dog', exist_ok=True)

# %%
# 30枚を検証データに
for filenum in range(30):
  shutil.move('drive/MyDrive/Colab Notebooks/dataset/inuneko/train/dog/' +str(filenum+1).zfill(6)+'.jpg', 'drive/MyDrive/Colab Notebooks/dataset/inuneko/test/dog')

# %%
# 学習に必要なものをimport
import torch
import torch.nn as nn
import torch.optim as optim
import torch.onnx #Burracudaで使う用
import torchvision
from torchvision import datasets, models, transforms

import numpy as np
from tqdm import tqdm
from PIL import Image

# %%
# 画像の前処理
size = (224, 224)
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

train_data_dir = 'drive/MyDrive/Colab Notebooks/dataset/inuneko/train'
val_data_dir = 'drive/MyDrive/Colab Notebooks/dataset/inuneko/test'

image_datasets = {
    'val': torchvision.datasets.ImageFolder(val_data_dir, transform=data_transforms['val']),
    'train': torchvision.datasets.ImageFolder(train_data_dir, transform=data_transforms['train'])
}

# %%
# 学習データを取り出しやすくした形
dataloaders = {
    'train': torch.utils.data.DataLoader(image_datasets['train'], batch_size=10, shuffle=True),
    'val': torch.utils.data.DataLoader(image_datasets['val'], batch_size=1)
}

# %%
# 画像の枚数やラベルを定義
dataset_sizes = {
    'train': len(image_datasets['train']),
    'val': len(image_datasets['val'])
}

class_names = image_datasets['train'].classes
print('分類種類:', class_names)
# Out:
# 分類種類: ['cat', 'dog']

# %%
# 転移学習用のモデルのダウンロードと設定

model = models.vgg16(pretrained=True)

# パラメータの固定
for param in model.parameters():
    param.requires_grad = False

# 最後の全結合層を固定しない＞ここだけ学習する
last_layer = list(model.children())[-1]
for param in last_layer.parameters():
    param.requires_grad = True

# 学習時にGPUを使えるなら使う
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Burracudaで学習させたい場合はCPUを使う
device = torch.device("cpu")


# 分類数を1000から2つに変更
num_ftrs = model.classifier[6].in_features
model.classifier[6] = torch.nn.Linear(num_ftrs, len(class_names))
model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
# loss関数の定義

# lossを定義
criterion = nn.CrossEntropyLoss()

# 色々な最適化関数 lrが学習率 0.001 0.0001などで調整
optimizer = optim.Adam(model.parameters(), lr=0.0001,)
# optimizer = optim.SGD(model.parameters(), lr=0.001,)

# %%
# 学習部分の定義

def train(model, dataloader, otpimizer, criterion, num_epochs, device):
    """
    model:学習モデル
    dataloader:学習、評価データのdataloader
    optimizer:最適化関数
    crierion:ロス関数
    num_epochs:学習回数
    device:CPUかGPUか
    """
    best_acc = 0.0
    # 学習を繰り返す
    for epoch in range(num_epochs):
        # trainとvalを繰り返す
        for phase in ['train', 'val']:
            # モデルを学習モードか評価モードに切り替える
            if phase == 'train':
                model.train()
            else:
                model.eval()
            
            # 精度計算用
            loss_sum = 0.0
            acc_sum = 0.0
            total = 0

            # 進捗の表示
            with tqdm(total=len(dataloaders[phase]),unit="batch") as pbar:
                pbar.set_description(f"Epoch[{epoch}/{num_epochs}]({phase})")
                
                # dataloadersからバッチサイズに応じてデータを取得
                for inputs, labels in dataloaders[phase]:
                    # 画像とラベルをGPU/CPUか切り替え
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # 予測
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    
                    # ロス算出
                    loss = criterion(outputs, labels)

                    # 予測とラベルの差を使って学習 
                    if phase == 'train':
                        # ここは決まり文句
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()

                    # ロス、精度を算出
                    total += inputs.size(0)
                    loss_sum += loss.item() * inputs.size(0)
                    acc_sum += torch.sum(preds == labels.data).item()
                    # 進捗の表示
                    pbar.set_postfix({"loss":loss_sum/float(total),"accuracy":float(acc_sum)/float(total)})
                    pbar.update(1)

            # 1エポックでのロス、精度を算出
            epoch_loss = loss_sum / dataset_sizes[phase]
            epoch_acc = acc_sum / dataset_sizes[phase]

            # 一番良い制度の時にモデルデータを保存
            if phase == 'val' and epoch_acc > best_acc:
                print(f"save model epoch:{epoch} loss:{epoch_loss} acc:{epoch_acc}")

                dummy_input = torch.randn(1, 3, 224, 224)
                torch.onnx.export(model, dummy_input,'best_model.onnx') # Burracudaで使うようの形式で出力
                torch.save(model, 'best_model.pth')

# %%
# 学習開始

num_epochs = 10
train(model, dataloaders, optimizer, criterion, num_epochs, device)
# Out:
# Epoch[0/10](train):   0%|          | 0/14 [00:00<?, ?batch/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch[0/10](train): 100%|██████████| 14/14 [02:02<00:00,  8.76s/batch, loss=0.471, accuracy=0.742]
# Epoch[0/10](val): 100%|██████████| 60/60 [00:56<00:00,  1.07batch/s, loss=0.131, accuracy=0.933]
# save model epoch:0 loss:0.13077660098541108 acc:0.9333333333333333
# Epoch[1/10](train): 100%|██████████| 14/14 [01:32<00:00,  6.60s/batch, loss=0.0259, accuracy=0.992]
# Epoch[1/10](val): 100%|██████████| 60/60 [00:37<00:00,  1.61batch/s, loss=0.00162, accuracy=1]
# save model epoch:1 loss:0.0016232235678252493 acc:1.0
# Epoch[2/10](train): 100%|██████████| 14/14 [01:31<00:00,  6.55s/batch, loss=0.000267, accuracy=1]
# Epoch[2/10](val):  78%|███████▊  | 47/60 [00:29<00:07,  1.66batch/s, loss=0.000371, accuracy=1]

# %%
# 学習モデルの使用

best_model = torch.load('best_model.pth') # 学習モデルの読み込み

# 対象画像
filepath = "drive/MyDrive/Colab Notebooks/images/"
filename = 'dog02'
filetype = ".jpg" 

# 読み込み画像をリサイズやtensorなどの方に変換
input_image = Image.open(filepath + filename + filetype)
preprocess = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
input_tensor = preprocess(input_image)
input_batch = input_tensor.unsqueeze(0)

# GPU使える場合はGPUを使う
if torch.cuda.is_available():
    input_batch = input_batch.to('cuda')
    best_model.to('cuda')

# AIの判定
with torch.no_grad():
    output = best_model(input_batch)
output = torch.nn.functional.softmax(output[0], dim=0)
print(output.shape)

# 出力結果から2種類のうちどれかを数値で取得
output = output.to('cpu').detach().numpy().copy()
ind = np.argmax(output)
print(class_names[ind])
