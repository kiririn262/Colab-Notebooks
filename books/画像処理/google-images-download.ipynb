# %%
# !git clone https://github.com/Joeclinton1/google-images-download.git gid-joeclinton
# !pip install -e gid-joeclinton
# Out:
# Cloning into 'gid-joeclinton'...
# remote: Enumerating objects: 719, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 719 (delta 32), reused 48 (delta 32), pack-reused 666
# Receiving objects: 100% (719/719), 319.77 KiB | 1.21 MiB/s, done.
# Resolving deltas: 100% (422/422), done.
# Obtaining file:///content/gid-joeclinton
# ...
#      |████████████████████████████████| 954 kB 16.8 MB/s
# ...
#      |████████████████████████████████| 138 kB 58.4 MB/s
# ...
#      |████████████████████████████████| 356 kB 59.5 MB/s
# ...
#      |████████████████████████████████| 55 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 53.6 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.2 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Running setup.py develop for google-images-download
# ...

# %%
keyword = "きのこの山"
# !googleimagesdownload --keywords {keyword} -l 10 # maxは100
# Out:
# Item no.: 1 --> Item name = \u304d\u306e\u3053\u306e\u5c71
# Evaluating...
# Starting Download...
# Completed Image ====> 1.thumb.jpg
# Completed Image ====> 2.71i7ifskdol._ac_sx679_.jpg
# Completed Image ====> 3.y_5df8a328ec61d.jpg
# Completed Image ====> 4.71fuju9coql._ac_sx679_.jpg
# Completed Image ====> 5.8d5a8051-l.jpg
# Completed Image ====> 6.cover-kinotake.png
# Completed Image ====> 7.img_d21eb6b758c4801b96b073b216e345bf2136104.jpg
# Completed Image ====> 8.kinoko-20190312001500.jpg
# Completed Image ====> 9.4902777008592_1_l.jpg
# Completed Image ====> 10.l_kutsu_210322kinoko01.jpg
#
# Errors: 0
#
#
# Everything downloaded!
# Total errors: 0
# Total time taken: 23.089178562164307 Seconds

# %%
words = ["きのこの山 実物", "きのこの山 形", "海", "山"]

# %%
for word in words:
  # !googleimagesdownload --keywords {word} -l 30
# Out:
# usage: googleimagesdownload [-h] [-k KEYWORDS] [-kf KEYWORDS_FROM_FILE]
#                             [-sk SUFFIX_KEYWORDS] [-pk PREFIX_KEYWORDS]
#                             [-l LIMIT] [-f {jpg,gif,png,bmp,svg,webp,ico}]
#                             [-u URL] [-x SINGLE_IMAGE] [-o OUTPUT_DIRECTORY]
#                             [-i IMAGE_DIRECTORY] [-n] [-d DELAY]
#                             [-co {red,orange,yellow,green,teal,blue,purple,pink,white,gray,black,brown}]
#                             [-ct {full-color,black-and-white,transparent}]
#                             [-r {labeled-for-reuse-with-modifications,labeled-for-reuse,labeled-for-noncommercial-reuse-with-modification,labeled-for-nocommercial-reuse}]
#                             [-s {large,medium,icon,>400*300,>640*480,>800*600,>1024*768,>2MP,>4MP,>6MP,>8MP,>10MP,>12MP,>15MP,>20MP,>40MP,>70MP}]
#                             [-es EXACT_SIZE]
# ...
